# %% [markdown]
# # mplot3d 工具包
# 3D Axes通过给`Figure.add_subplot`传递`projection="3d"`参数获取。

# %%
import matplotlib.pyplot as plt
from torch_scatter import scatter_mean

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(1, 1, 1, c='r', marker='o')

# %%
plt.show()
